# %%
import pandas
data = pandas.read_csv('titanic.csv', index_col='PassengerId')

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
data_male = data[data.Sex == 'male']

# %%
data_male.shape
# Out:
# (577, 11)

# %%
data_female = data[data.Sex == 'female']

# %%
data_female.shape
# Out:
# (314, 11)

# %%
data_survived = data[data.Survived == 1]

# %%
data_survived.shape
# Out:
# (342, 11)

# %%
(data_survived.shape[0]/data.shape[0])*100
# Out:
# 38.38383838383838

# %%
data_fclass = data[data.Pclass == 1]

# %%
(data_fclass.shape[0]/data.shape[0])*100
# Out:
# 24.242424242424242

# %%
data.Age.mean()
# Out:
# 29.69911764705882

# %%
data['Age'].median()
# Out:
# 28.0

# %%
data['SibSp'].corr(data['Parch'])
# Out:
# 0.4148376986201567

# %%
data_female['Name'].mode()
# Out:
# 0                       Abbott, Mrs. Stanton (Rosa Hunt)
# 1                  Abelson, Mrs. Samuel (Hannah Wizosky)
# 2         Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 3                             Aks, Mrs. Sam (Leah Rosen)
# 4                          Allen, Miss. Elisabeth Walton
# 5                           Allison, Miss. Helen Loraine
# 6        Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7        Andersen-Jensen, Miss. Carla Christine Nielsine
# 8                     Andersson, Miss. Ebba Iris Alfrida
# 9                      Andersson, Miss. Ellis Anna Maria
# 10                       Andersson, Miss. Erna Alexandra
# 11                  Andersson, Miss. Ingeborg Constanzia
# 12                     Andersson, Miss. Sigrid Elisabeth
# 13     Andersson, Mrs. Anders Johan (Alfrida Konstant...
# 14                     Andrews, Miss. Kornelia Theodosia
# 15     Angle, Mrs. William A (Florence "Mary" Agnes H...
# ...

# %%
data_female
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 15                  0       3
# 16                  1       2
# 19                  0       3
# 20                  1       3
# 23                  1       3
# 25                  0       3
# 26                  1       3
# 29                  1       3
# 32                  1       1
# 33                  1       3
# 39                  0       3
# 40                  1       3
# 41                  0       3
# 42                  0       2
# 44                  1       2
# 45                  1       3
# 48                  1       3
# 50                  0       3
# 53                  1       1
# 54                  1       2
# 57                  1       2
# 59                  1       2
# ...
